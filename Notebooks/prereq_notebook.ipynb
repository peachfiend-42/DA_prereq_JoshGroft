# %%
print("Good morning, heartache.")
# Out:
# Good morning, heartache.

# %% [markdown]
# Hey, hi, hello.
# * I'm Josh. Age 44, love dogs, poetry, long walks in the woods, etc.
# * Strange time to introduce myself, since I'm recently out as a trans woman. That might be TMI, but since we don't know each other yet, it may save questions later. For example, if I stop introducing myself as Josh.
# * Excited to learn: Python, generally. I'm a long-time Linux user, going back to 1996. I taught myself QBasic in the 5th grade, and HTML in 9th grade (ah, Netscape...). But I've never succeeded at teaching myself Python because learning stuff all by yourself as an adult can be difficult.
# * SQL will probably also end up being useful to me. I do some data analysis professionally, but the proprietary reporting on offer is... lacking, IMHO. i.e. I am collecting data captures in CSV format on my work machine that I have objectives for. Strictly for myself, at the moment, though there's some opportunity to push what I come up with to our enterprise team for other people in my role to use.
# * Also, if not already obvious, I trend verbose when given the opportunity. So that's enough for now.
